# %% [markdown]
# Given MRI images from different perspectives (Sagittal T1, Axial T2, and Sagittal T2/STIR),<br> the goal is to build a classifier that can identify and classify these images into one of the three classes.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import os
import time
import numpy as np
import glob
import json
import collections
import torch
import torch.nn as nn
import pydicom as dicom
import matplotlib.patches as patches
from matplotlib import animation, rc
import pandas as pd
import pydicom as dicom 
import pydicom
from pydicom.pixel_data_handlers.util import apply_voi_lut
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch.optim.lr_scheduler as lr_scheduler
from tqdm import tqdm
import torchvision.models as models
from torchvision import transforms
from sklearn.model_selection import train_test_split

# %%
train_path = 'data/input/rsna-2024-lumbar-spine-degenerative-classification/'

train  = pd.read_csv(train_path + 'train.csv')
label = pd.read_csv(train_path + 'train_label_coordinates.csv')
train_desc  = pd.read_csv(train_path + 'train_series_descriptions.csv')
test_desc   = pd.read_csv(train_path + 'test_series_descriptions.csv')
sub         = pd.read_csv(train_path + 'sample_submission.csv')

# %%
#test_desc.head(5)

# %%
#train.head(5)

# %%
#train_desc.head(5)

# %%
# Function to generate image paths based on directory structure
def generate_image_paths(df, data_dir):
    image_paths = []
    for study_id, series_id in zip(df['study_id'], df['series_id']):
        study_dir = os.path.join(data_dir, str(study_id))
        series_dir = os.path.join(study_dir, str(series_id))
        images = os.listdir(series_dir)
        image_paths.extend([os.path.join(series_dir, img) for img in images])
    return image_paths

# Generate image paths for train and test data
train_image_paths = generate_image_paths(train_desc, f'{train_path}/train_images')
test_image_paths = generate_image_paths(test_desc, f'{train_path}/test_images')

# %%
len(train_desc),len(train_image_paths)
# Out:
# (6294, 147218)

# %%
# Function to open and display DICOM images
def display_dicom_images(image_paths):
    plt.figure(figsize=(15, 5))
    for i, path in enumerate(image_paths[:3]):
        ds = pydicom.dcmread(path)
        plt.subplot(1, 3, i+1)
        plt.imshow(ds.pixel_array, cmap=plt.cm.bone)
        plt.title(f"Image {i+1}")
        plt.axis('off')
    plt.show()

# Display the first three DICOM images
display_dicom_images(train_image_paths)

# %%
# Function to open and display DICOM images along with coordinates
def display_dicom_with_coordinates(image_paths, label_df):
    fig, axs = plt.subplots(1, len(image_paths), figsize=(18, 6))
    
    for idx, path in enumerate(image_paths):
        print(f"Processing path: {path}")
        
        try:
            study_id = int(os.path.basename(os.path.dirname(os.path.dirname(path))))
            series_id = int(os.path.basename(os.path.dirname(path)))
        except (IndexError, ValueError) as e:
            print(f"Error processing path: {path} - {e}")
            continue
        
        # Filter label coordinates for the current study and series
        filtered_labels = label_df[(label_df['study_id'] == study_id) & (label_df['series_id'] == series_id)]
        
        ds = pydicom.dcmread(path)
        
        axs[idx].imshow(ds.pixel_array, cmap='gray')
        axs[idx].set_title(f"Study ID: {study_id}, Series ID: {series_id}")
        axs[idx].axis('off')
        
        for _, row in filtered_labels.iterrows():
            axs[idx].plot(row['x'], row['y'], 'ro', markersize=5)
        
    plt.tight_layout()
    plt.show()

display_dicom_with_coordinates(image_paths, label)
# Out:
# Processing path: data/input/rsna-2024-lumbar-spine-degenerative-classification//train_images/100206310\1012284084\1.dcm
# Processing path: data/input/rsna-2024-lumbar-spine-degenerative-classification//train_images/100206310\1792451510\1.dcm
# Processing path: data/input/rsna-2024-lumbar-spine-degenerative-classification//train_images/100206310\2092806862\1.dcm

# %%
# Define function to reshape a single row of the DataFrame
def reshape_row(row):
    data = {'study_id': [], 'condition': [], 'level': [], 'severity': []}
    
    for column, value in row.items():
        if column not in ['study_id', 'series_id', 'instance_number', 'x', 'y', 'series_description']:
            parts = column.split('_')
            condition = ' '.join([word.capitalize() for word in parts[:-2]])
            level = parts[-2].capitalize() + '/' + parts[-1].capitalize()
            data['study_id'].append(row['study_id'])
            data['condition'].append(condition)
            data['level'].append(level)
            data['severity'].append(value)
    
    return pd.DataFrame(data)

# Reshape the DataFrame for all rows
new_train_df = pd.concat([reshape_row(row) for _, row in train.iterrows()], ignore_index=True)

# Display the first few rows of the reshaped dataframe
new_train_df.head(5)
# Out:
#    study_id              condition  level     severity
# 0   4003253  Spinal Canal Stenosis  L1/L2  Normal/Mild
# 1   4003253  Spinal Canal Stenosis  L2/L3  Normal/Mild
# 2   4003253  Spinal Canal Stenosis  L3/L4  Normal/Mild
# 3   4003253  Spinal Canal Stenosis  L4/L5  Normal/Mild
# 4   4003253  Spinal Canal Stenosis  L5/S1  Normal/Mild

# %%
'''print("\nColumns in new_train_df:")
print(",".join(new_train_df.columns))

print("\nColumns in label:")
print(",".join(label.columns))

print("\nColumns in test_desc:")
print(",".join(test_desc.columns))

print("\nColumns in sub:")
print(",".join(sub.columns))'''
# Out:
# 'print("\nColumns in new_train_df:")\nprint(",".join(new_train_df.columns))\n\nprint("\nColumns in label:")\nprint(",".join(label.columns))\n\nprint("\nColumns in test_desc:")\nprint(",".join(test_desc.columns))\n\nprint("\nColumns in sub:")\nprint(",".join(sub.columns))'

# %%
# Merge the dataframes on the common columns
merged_df = pd.merge(new_train_df, label, on=['study_id', 'condition', 'level'], how='inner')
# Merge the dataframes on the common column 'series_id'
final_merged_df = pd.merge(merged_df, train_desc, on='series_id', how='inner')

# %%
# Merge the dataframes on the common column 'series_id'
final_merged_df = pd.merge(merged_df, train_desc, on=['series_id','study_id'], how='inner')

final_merged_df.head(5)
# Out:
#    study_id              condition  level     severity  series_id  \
# 0   4003253  Spinal Canal Stenosis  L1/L2  Normal/Mild  702807833
# 1   4003253  Spinal Canal Stenosis  L2/L3  Normal/Mild  702807833
# 2   4003253  Spinal Canal Stenosis  L3/L4  Normal/Mild  702807833
# 3   4003253  Spinal Canal Stenosis  L4/L5  Normal/Mild  702807833
# 4   4003253  Spinal Canal Stenosis  L5/S1  Normal/Mild  702807833
#
#    instance_number           x           y series_description
# 0                8  322.831858  227.964602   Sagittal T2/STIR
# 1                8  320.571429  295.714286   Sagittal T2/STIR
# 2                8  323.030303  371.818182   Sagittal T2/STIR
# 3                8  335.292035  427.327434   Sagittal T2/STIR
# 4                8  353.415929  483.964602   Sagittal T2/STIR

# %%
final_merged_df[final_merged_df['study_id'] == 100206310].sort_values(['x','y'],ascending = True)
# Out:
#        study_id                         condition  level     severity  \
# 1136  100206310       Right Subarticular Stenosis  L5/S1     Moderate
# 1132  100206310       Right Subarticular Stenosis  L1/L2  Normal/Mild
# 1133  100206310       Right Subarticular Stenosis  L2/L3  Normal/Mild
# 1135  100206310       Right Subarticular Stenosis  L4/L5     Moderate
# 1134  100206310       Right Subarticular Stenosis  L3/L4     Moderate
# 1131  100206310        Left Subarticular Stenosis  L5/S1     Moderate
# 1130  100206310        Left Subarticular Stenosis  L4/L5       Severe
# 1129  100206310        Left Subarticular Stenosis  L3/L4     Moderate
# 1128  100206310        Left Subarticular Stenosis  L2/L3  Normal/Mild
# 1127  100206310        Left Subarticular Stenosis  L1/L2  Normal/Mild
# 1114  100206310             Spinal Canal Stenosis  L3/L4     Moderate
# 1113  100206310             Spinal Canal Stenosis  L2/L3  Normal/Mild
# 1115  100206310             Spinal Canal Stenosis  L4/L5       Severe
# 1112  100206310             Spinal Canal Stenosis  L1/L2  Normal/Mild
# 1116  100206310             Spinal Canal Stenosis  L5/S1  Normal/Mild
# 1120  100206310   Left Neural Foraminal Narrowing  L4/L5       Severe
# 1119  100206310   Left Neural Foraminal Narrowing  L3/L4     Moderate
# 1124  100206310  Right Neural Foraminal Narrowing  L3/L4       Severe
# 1126  100206310  Right Neural Foraminal Narrowing  L5/S1  Normal/Mild
# 1125  100206310  Right Neural Foraminal Narrowing  L4/L5     Moderate
# 1123  100206310  Right Neural Foraminal Narrowing  L2/L3     Moderate
# 1121  100206310   Left Neural Foraminal Narrowing  L5/S1     Moderate
# 1118  100206310   Left Neural Foraminal Narrowing  L2/L3     Moderate
# 1122  100206310  Right Neural Foraminal Narrowing  L1/L2     Moderate
# 1117  100206310   Left Neural Foraminal Narrowing  L1/L2  Normal/Mild
#
#        series_id  instance_number           x           y series_description
# 1136  1012284084               55  145.120536  159.428571           Axial T2
# 1132  1012284084               20  145.120536  162.285714           Axial T2
# 1133  1012284084               28  145.691964  160.000000           Axial T2
# 1135  1012284084               46  146.263393  160.000000           Axial T2
# 1134  1012284084               37  147.406250  161.142857           Axial T2
# 1131  1012284084               55  167.660739  157.154583           Axial T2
# 1130  1012284084               46  168.536252  156.279070           Axial T2
# 1129  1012284084               37  173.351573  158.467852           Axial T2
# 1128  1012284084               28  177.729138  160.218878           Axial T2
# 1127  1012284084               20  180.355677  165.034200           Axial T2
# 1114  1792451510                9  225.810983  257.762195   Sagittal T2/STIR
# 1113  1792451510                9  229.030495  203.030488   Sagittal T2/STIR
# 1115  1792451510                9  231.445129  316.518293   Sagittal T2/STIR
# 1112  1792451510                9  240.298788  151.518293   Sagittal T2/STIR
# 1116  1792451510                9  247.542690  360.786585   Sagittal T2/STIR
# 1120  2092806862               12  249.241774  274.786914        Sagittal T1
# 1119  2092806862               13  250.176889  234.398551        Sagittal T1
# 1124  2092806862                5  252.350305  235.926680        Sagittal T1
# 1126  2092806862                4  252.350305  320.391039        Sagittal T1
# 1125  2092806862                4  253.393075  278.680244        Sagittal T1
# 1123  2092806862                6  256.521385  186.916497        Sagittal T1
# 1121  2092806862               12  258.806490  319.853318        Sagittal T1
# 1118  2092806862               12  260.177602  191.705532        Sagittal T1
# 1122  2092806862                6  265.906314  146.248473        Sagittal T1
# 1117  2092806862               13  270.342250  148.221459        Sagittal T1

# %%
final_merged_df[final_merged_df['series_id'] == 1012284084].sort_values("instance_number")
# Out:
#        study_id                    condition  level     severity   series_id  \
# 1127  100206310   Left Subarticular Stenosis  L1/L2  Normal/Mild  1012284084
# 1132  100206310  Right Subarticular Stenosis  L1/L2  Normal/Mild  1012284084
# 1128  100206310   Left Subarticular Stenosis  L2/L3  Normal/Mild  1012284084
# 1133  100206310  Right Subarticular Stenosis  L2/L3  Normal/Mild  1012284084
# 1129  100206310   Left Subarticular Stenosis  L3/L4     Moderate  1012284084
# 1134  100206310  Right Subarticular Stenosis  L3/L4     Moderate  1012284084
# 1130  100206310   Left Subarticular Stenosis  L4/L5       Severe  1012284084
# 1135  100206310  Right Subarticular Stenosis  L4/L5     Moderate  1012284084
# 1131  100206310   Left Subarticular Stenosis  L5/S1     Moderate  1012284084
# 1136  100206310  Right Subarticular Stenosis  L5/S1     Moderate  1012284084
#
#       instance_number           x           y series_description
# 1127               20  180.355677  165.034200           Axial T2
# 1132               20  145.120536  162.285714           Axial T2
# 1128               28  177.729138  160.218878           Axial T2
# 1133               28  145.691964  160.000000           Axial T2
# 1129               37  173.351573  158.467852           Axial T2
# 1134               37  147.406250  161.142857           Axial T2
# 1130               46  168.536252  156.279070           Axial T2
# 1135               46  146.263393  160.000000           Axial T2
# 1131               55  167.660739  157.154583           Axial T2
# 1136               55  145.120536  159.428571           Axial T2

# %%
# Filter the dataframe for the given study_id and sort by instance_number
filtered_df = final_merged_df[final_merged_df['study_id'] == 1013589491].sort_values("instance_number")

filtered_df
# Out:
#          study_id                         condition  level     severity  \
# 11430  1013589491   Left Neural Foraminal Narrowing  L5/S1  Normal/Mild
# 11445  1013589491       Right Subarticular Stenosis  L5/S1  Normal/Mild
# 11440  1013589491        Left Subarticular Stenosis  L5/S1  Normal/Mild
# 11429  1013589491   Left Neural Foraminal Narrowing  L4/L5  Normal/Mild
# 11428  1013589491   Left Neural Foraminal Narrowing  L3/L4  Normal/Mild
# 11426  1013589491   Left Neural Foraminal Narrowing  L1/L2  Normal/Mild
# 11427  1013589491   Left Neural Foraminal Narrowing  L2/L3  Normal/Mild
# 11421  1013589491             Spinal Canal Stenosis  L1/L2  Normal/Mild
# 11424  1013589491             Spinal Canal Stenosis  L4/L5     Moderate
# 11423  1013589491             Spinal Canal Stenosis  L3/L4     Moderate
# 11422  1013589491             Spinal Canal Stenosis  L2/L3  Normal/Mild
# 11425  1013589491             Spinal Canal Stenosis  L5/S1  Normal/Mild
# 11431  1013589491  Right Neural Foraminal Narrowing  L1/L2  Normal/Mild
# 11444  1013589491       Right Subarticular Stenosis  L4/L5  Normal/Mild
# 11439  1013589491        Left Subarticular Stenosis  L4/L5     Moderate
# 11433  1013589491  Right Neural Foraminal Narrowing  L3/L4  Normal/Mild
# 11435  1013589491  Right Neural Foraminal Narrowing  L5/S1  Normal/Mild
# 11434  1013589491  Right Neural Foraminal Narrowing  L4/L5  Normal/Mild
# 11432  1013589491  Right Neural Foraminal Narrowing  L2/L3  Normal/Mild
# 11438  1013589491        Left Subarticular Stenosis  L3/L4     Moderate
# 11443  1013589491       Right Subarticular Stenosis  L3/L4  Normal/Mild
# 11442  1013589491       Right Subarticular Stenosis  L2/L3  Normal/Mild
# 11437  1013589491        Left Subarticular Stenosis  L2/L3  Normal/Mild
# 11441  1013589491       Right Subarticular Stenosis  L1/L2  Normal/Mild
# 11436  1013589491        Left Subarticular Stenosis  L1/L2  Normal/Mild
#
#         series_id  instance_number           x           y series_description
# 11430  2391548363                6  240.770301  411.216131        Sagittal T1
# 11445   598943280                7  231.484002  293.409742           Axial T2
# 11440   598943280                7  277.947591  296.033812           Axial T2
# 11429  2391548363                7  227.194543  355.943404        Sagittal T1
# 11428  2391548363                7  222.346058  293.844904        Sagittal T1
# 11426  2391548363                7  247.558179  177.458555        Sagittal T1
# 11427  2391548363                7  233.012725  234.685828        Sagittal T1
# 11421   482346415               10  245.476038  189.689334   Sagittal T2/STIR
# 11424   482346415               10  238.435979  366.511699   Sagittal T2/STIR
# 11423   482346415               10  232.381129  310.201597   Sagittal T2/STIR
# 11422   482346415               10  235.251580  250.434645   Sagittal T2/STIR
# 11425   482346415               10  257.921341  421.652869   Sagittal T2/STIR
# 11431  2391548363               13  248.575673  181.125348        Sagittal T1
# 11444   598943280               13  228.060888  255.755492           Axial T2
# 11439   598943280               13  266.694844  257.081995           Axial T2
# 11433  2391548363               14  223.855153  299.498607        Sagittal T1
# 11435  2391548363               14  244.297122  419.298050        Sagittal T1
# 11434  2391548363               14  226.707521  364.152275        Sagittal T1
# 11432  2391548363               14  231.936862  234.369545        Sagittal T1
# 11438   598943280               19  262.366864  246.262046           Axial T2
# 11443   598943280               19  215.835482  245.486151           Axial T2
# 11442   598943280               26  216.813515  245.486151           Axial T2
# 11437   598943280               26  262.799662  242.799662           Axial T2
# 11441   598943280               33  221.214661  260.645654           Axial T2
# 11436   598943280               33  273.186813  256.649197           Axial T2

# %%
sorted_final_merged_df = final_merged_df[final_merged_df['study_id'] == 1013589491].sort_values(by=['series_id', 'series_description', 'instance_number'])
sorted_final_merged_df
# Out:
#          study_id                         condition  level     severity  \
# 11421  1013589491             Spinal Canal Stenosis  L1/L2  Normal/Mild
# 11422  1013589491             Spinal Canal Stenosis  L2/L3  Normal/Mild
# 11423  1013589491             Spinal Canal Stenosis  L3/L4     Moderate
# 11424  1013589491             Spinal Canal Stenosis  L4/L5     Moderate
# 11425  1013589491             Spinal Canal Stenosis  L5/S1  Normal/Mild
# 11440  1013589491        Left Subarticular Stenosis  L5/S1  Normal/Mild
# 11445  1013589491       Right Subarticular Stenosis  L5/S1  Normal/Mild
# 11439  1013589491        Left Subarticular Stenosis  L4/L5     Moderate
# 11444  1013589491       Right Subarticular Stenosis  L4/L5  Normal/Mild
# 11438  1013589491        Left Subarticular Stenosis  L3/L4     Moderate
# 11443  1013589491       Right Subarticular Stenosis  L3/L4  Normal/Mild
# 11437  1013589491        Left Subarticular Stenosis  L2/L3  Normal/Mild
# 11442  1013589491       Right Subarticular Stenosis  L2/L3  Normal/Mild
# 11436  1013589491        Left Subarticular Stenosis  L1/L2  Normal/Mild
# 11441  1013589491       Right Subarticular Stenosis  L1/L2  Normal/Mild
# 11430  1013589491   Left Neural Foraminal Narrowing  L5/S1  Normal/Mild
# 11426  1013589491   Left Neural Foraminal Narrowing  L1/L2  Normal/Mild
# 11427  1013589491   Left Neural Foraminal Narrowing  L2/L3  Normal/Mild
# 11428  1013589491   Left Neural Foraminal Narrowing  L3/L4  Normal/Mild
# 11429  1013589491   Left Neural Foraminal Narrowing  L4/L5  Normal/Mild
# 11431  1013589491  Right Neural Foraminal Narrowing  L1/L2  Normal/Mild
# 11432  1013589491  Right Neural Foraminal Narrowing  L2/L3  Normal/Mild
# 11433  1013589491  Right Neural Foraminal Narrowing  L3/L4  Normal/Mild
# 11434  1013589491  Right Neural Foraminal Narrowing  L4/L5  Normal/Mild
# 11435  1013589491  Right Neural Foraminal Narrowing  L5/S1  Normal/Mild
#
#         series_id  instance_number           x           y series_description
# 11421   482346415               10  245.476038  189.689334   Sagittal T2/STIR
# 11422   482346415               10  235.251580  250.434645   Sagittal T2/STIR
# 11423   482346415               10  232.381129  310.201597   Sagittal T2/STIR
# 11424   482346415               10  238.435979  366.511699   Sagittal T2/STIR
# 11425   482346415               10  257.921341  421.652869   Sagittal T2/STIR
# 11440   598943280                7  277.947591  296.033812           Axial T2
# 11445   598943280                7  231.484002  293.409742           Axial T2
# 11439   598943280               13  266.694844  257.081995           Axial T2
# 11444   598943280               13  228.060888  255.755492           Axial T2
# 11438   598943280               19  262.366864  246.262046           Axial T2
# 11443   598943280               19  215.835482  245.486151           Axial T2
# 11437   598943280               26  262.799662  242.799662           Axial T2
# 11442   598943280               26  216.813515  245.486151           Axial T2
# 11436   598943280               33  273.186813  256.649197           Axial T2
# 11441   598943280               33  221.214661  260.645654           Axial T2
# 11430  2391548363                6  240.770301  411.216131        Sagittal T1
# 11426  2391548363                7  247.558179  177.458555        Sagittal T1
# 11427  2391548363                7  233.012725  234.685828        Sagittal T1
# 11428  2391548363                7  222.346058  293.844904        Sagittal T1
# 11429  2391548363                7  227.194543  355.943404        Sagittal T1
# 11431  2391548363               13  248.575673  181.125348        Sagittal T1
# 11432  2391548363               14  231.936862  234.369545        Sagittal T1
# 11433  2391548363               14  223.855153  299.498607        Sagittal T1
# 11434  2391548363               14  226.707521  364.152275        Sagittal T1
# 11435  2391548363               14  244.297122  419.298050        Sagittal T1

# %% [markdown]
# We see that,<br>
# Saggital T1 images map to Neural Foraminal Narrowing<br>
# Axial T2 images map to Subarticular Stenosis<br>
# Saggital T2/STIR map to Canal Stenosis

# %%
# Create the row_id column
final_merged_df['row_id'] = (
    final_merged_df['study_id'].astype(str) + '_' +
    final_merged_df['condition'].str.lower().str.replace(' ', '_') + '_' +
    final_merged_df['level'].str.lower().str.replace('/', '_')
)

# Create the image_path column
final_merged_df['image_path'] = (
    f'{train_path}/train_images/' + 
    final_merged_df['study_id'].astype(str) + '/' +
    final_merged_df['series_id'].astype(str) + '/' +
    final_merged_df['instance_number'].astype(str) + '.dcm'
)


final_merged_df.head(5)
# Out:
#    study_id              condition  level     severity  series_id  \
# 0   4003253  Spinal Canal Stenosis  L1/L2  Normal/Mild  702807833
# 1   4003253  Spinal Canal Stenosis  L2/L3  Normal/Mild  702807833
# 2   4003253  Spinal Canal Stenosis  L3/L4  Normal/Mild  702807833
# 3   4003253  Spinal Canal Stenosis  L4/L5  Normal/Mild  702807833
# 4   4003253  Spinal Canal Stenosis  L5/S1  Normal/Mild  702807833
#
#    instance_number           x           y series_description  \
# 0                8  322.831858  227.964602   Sagittal T2/STIR
# 1                8  320.571429  295.714286   Sagittal T2/STIR
# 2                8  323.030303  371.818182   Sagittal T2/STIR
# 3                8  335.292035  427.327434   Sagittal T2/STIR
# 4                8  353.415929  483.964602   Sagittal T2/STIR
#
#                                 row_id  \
# 0  4003253_spinal_canal_stenosis_l1_l2
# 1  4003253_spinal_canal_stenosis_l2_l3
# 2  4003253_spinal_canal_stenosis_l3_l4
# 3  4003253_spinal_canal_stenosis_l4_l5
# 4  4003253_spinal_canal_stenosis_l5_s1
#
#                                           image_path
# 0  data/input/rsna-2024-lumbar-spine-degenerative...
# 1  data/input/rsna-2024-lumbar-spine-degenerative...
# 2  data/input/rsna-2024-lumbar-spine-degenerative...
# 3  data/input/rsna-2024-lumbar-spine-degenerative...
# 4  data/input/rsna-2024-lumbar-spine-degenerative...

# %%
final_merged_df[final_merged_df["severity"] == "Normal/Mild"].value_counts().sum()
# Out:
# 37626

# %%
final_merged_df[final_merged_df["severity"] == "Moderate"].value_counts().sum()
# Out:
# 7950

# %%
# Define the base path for test images
base_path = 'data/input/rsna-2024-lumbar-spine-degenerative-classification/test_images/'

# Function to get image paths for a series
def get_image_paths(row):
    series_path = os.path.join(base_path, str(row['study_id']), str(row['series_id']))
    if os.path.exists(series_path):
        return [os.path.join(series_path, f) for f in os.listdir(series_path) if os.path.isfile(os.path.join(series_path, f))]
    return []

# Mapping of series_description to conditions
condition_mapping = {
    'Sagittal T1': {'left': 'left_neural_foraminal_narrowing', 'right': 'right_neural_foraminal_narrowing'},
    'Axial T2': {'left': 'left_subarticular_stenosis', 'right': 'right_subarticular_stenosis'},
    'Sagittal T2/STIR': 'spinal_canal_stenosis'
}

# Create a list to store the expanded rows
expanded_rows = []

# Expand the dataframe by adding new rows for each file path
for index, row in test_desc.iterrows():
    image_paths = get_image_paths(row)
    conditions = condition_mapping.get(row['series_description'], {})
    if isinstance(conditions, str):  # Single condition
        conditions = {'left': conditions, 'right': conditions}
    for side, condition in conditions.items():
        for image_path in image_paths:
            expanded_rows.append({
                'study_id': row['study_id'],
                'series_id': row['series_id'],
                'series_description': row['series_description'],
                'image_path': image_path,
                'condition': condition,
                'row_id': f"{row['study_id']}_{condition}"
            })

# Create a new dataframe from the expanded rows
expanded_test_desc = pd.DataFrame(expanded_rows)

# Display the resulting dataframe
expanded_test_desc.head(5)
# Out:
#    study_id   series_id series_description  \
# 0  44036939  2828203845        Sagittal T1
# 1  44036939  2828203845        Sagittal T1
# 2  44036939  2828203845        Sagittal T1
# 3  44036939  2828203845        Sagittal T1
# 4  44036939  2828203845        Sagittal T1
#
#                                           image_path  \
# 0  data/input/rsna-2024-lumbar-spine-degenerative...
# 1  data/input/rsna-2024-lumbar-spine-degenerative...
# 2  data/input/rsna-2024-lumbar-spine-degenerative...
# 3  data/input/rsna-2024-lumbar-spine-degenerative...
# 4  data/input/rsna-2024-lumbar-spine-degenerative...
#
#                          condition                                    row_id
# 0  left_neural_foraminal_narrowing  44036939_left_neural_foraminal_narrowing
# 1  left_neural_foraminal_narrowing  44036939_left_neural_foraminal_narrowing
# 2  left_neural_foraminal_narrowing  44036939_left_neural_foraminal_narrowing
# 3  left_neural_foraminal_narrowing  44036939_left_neural_foraminal_narrowing
# 4  left_neural_foraminal_narrowing  44036939_left_neural_foraminal_narrowing

# %%
# change severity column labels
final_merged_df['severity'] = final_merged_df['severity'].map({'Normal/Mild': 'normal_mild', 'Moderate': 'moderate', 'Severe': 'severe'})

# %%
test_data = expanded_test_desc
train_data = final_merged_df

# %%
# Define a function to check if a path exists
def check_exists(path):
    return os.path.exists(path)

# Define a function to check if a study ID directory exists
def check_study_id(row):
    study_id = row['study_id']
    path = f'{train_path}/train_images/{study_id}'
    return check_exists(path)

# Define a function to check if a series ID directory exists
def check_series_id(row):
    study_id = row['study_id']
    series_id = row['series_id']
    path = f'{train_path}/train_images/{study_id}/{series_id}'
    return check_exists(path)

# Define a function to check if an image file exists
def check_image_exists(row):
    image_path = row['image_path']
    return check_exists(image_path)

# Apply the functions to the train_data dataframe
train_data['study_id_exists'] = train_data.apply(check_study_id, axis=1)
train_data['series_id_exists'] = train_data.apply(check_series_id, axis=1)
train_data['image_exists'] = train_data.apply(check_image_exists, axis=1)

train_data = train_data[(train_data['study_id_exists']) & (train_data['series_id_exists']) & (train_data['image_exists'])]

# %%
#train_data.head(3)

# %%
def load_dicom(path):
    dicom = pydicom.read_file(path)
    data = dicom.pixel_array
    data = data - np.min(data)
    if np.max(data) != 0:
        data = data / np.max(data)
    data = (data * 255).astype(np.uint8)
    return data

# %%
# Load images randomly
import random
images = []
row_ids = []
selected_indices = random.sample(range(len(train_data)), 2)
for i in selected_indices:
    image = load_dicom(train_data['image_path'][i])
    images.append(image)
    row_ids.append(train_data['row_id'][i])

fig, ax = plt.subplots(1, 2, figsize=(8, 4))
for i in range(2):
    ax[i].imshow(images[i], cmap='gray')
    ax[i].set_title(f'Row ID: {row_ids[i]}', fontsize=8)
    ax[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Loading data<h3>

# %%
train_data
# Out:
#          study_id                    condition  level     severity  \
# 0         4003253        Spinal Canal Stenosis  L1/L2  normal_mild
# 1         4003253        Spinal Canal Stenosis  L2/L3  normal_mild
# 2         4003253        Spinal Canal Stenosis  L3/L4  normal_mild
# 3         4003253        Spinal Canal Stenosis  L4/L5  normal_mild
# 4         4003253        Spinal Canal Stenosis  L5/S1  normal_mild
# ...           ...                          ...    ...          ...
# 48687  4290709089  Right Subarticular Stenosis  L1/L2  normal_mild
# 48688  4290709089  Right Subarticular Stenosis  L2/L3  normal_mild
# 48689  4290709089  Right Subarticular Stenosis  L3/L4  normal_mild
# 48690  4290709089  Right Subarticular Stenosis  L4/L5  normal_mild
# 48691  4290709089  Right Subarticular Stenosis  L5/S1  normal_mild
#
#         series_id  instance_number           x           y series_description  \
# 0       702807833                8  322.831858  227.964602   Sagittal T2/STIR
# 1       702807833                8  320.571429  295.714286   Sagittal T2/STIR
# 2       702807833                8  323.030303  371.818182   Sagittal T2/STIR
# 3       702807833                8  335.292035  427.327434   Sagittal T2/STIR
# 4       702807833                8  353.415929  483.964602   Sagittal T2/STIR
# ...           ...              ...         ...         ...                ...
# 48687  3390218084                2  307.180844  354.869960           Axial T2
# 48688  3390218084                6  301.440933  362.044847           Axial T2
# 48689  3390218084               10  302.875911  356.304937           Axial T2
# 48690  3390218084               15  305.745866  340.520184           Axial T2
# 48691  3390218084               21  302.875911  364.627811           Axial T2
#
#                                              row_id  \
# 0               4003253_spinal_canal_stenosis_l1_l2
# 1               4003253_spinal_canal_stenosis_l2_l3
# 2               4003253_spinal_canal_stenosis_l3_l4
# 3               4003253_spinal_canal_stenosis_l4_l5
# 4               4003253_spinal_canal_stenosis_l5_s1
# ...                                             ...
# 48687  4290709089_right_subarticular_stenosis_l1_l2
# 48688  4290709089_right_subarticular_stenosis_l2_l3
# 48689  4290709089_right_subarticular_stenosis_l3_l4
# 48690  4290709089_right_subarticular_stenosis_l4_l5
# 48691  4290709089_right_subarticular_stenosis_l5_s1
#
#                                               image_path  study_id_exists  \
# 0      data/input/rsna-2024-lumbar-spine-degenerative...             True
# 1      data/input/rsna-2024-lumbar-spine-degenerative...             True
# 2      data/input/rsna-2024-lumbar-spine-degenerative...             True
# 3      data/input/rsna-2024-lumbar-spine-degenerative...             True
# 4      data/input/rsna-2024-lumbar-spine-degenerative...             True
# ...                                                  ...              ...
# 48687  data/input/rsna-2024-lumbar-spine-degenerative...             True
# 48688  data/input/rsna-2024-lumbar-spine-degenerative...             True
# 48689  data/input/rsna-2024-lumbar-spine-degenerative...             True
# 48690  data/input/rsna-2024-lumbar-spine-degenerative...             True
# 48691  data/input/rsna-2024-lumbar-spine-degenerative...             True
#
#        series_id_exists  image_exists
# 0                  True          True
# 1                  True          True
# 2                  True          True
# 3                  True          True
# 4                  True          True
# ...                 ...           ...
# 48687              True          True
# 48688              True          True
# 48689              True          True
# 48690              True          True
# 48691              True          True
#
# [48692 rows x 14 columns]

# %%
#train_data = train_data.dropna()

# %%
# Define a custom dataset class
class CustomDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        image_path = self.dataframe['image_path'][index]
        image = load_dicom(image_path)
        label = self.dataframe['severity'][index]
        
        if self.transform:
            image = self.transform(image)

        return image, label

# Function to create datasets and dataloaders for each series description
def create_datasets_and_loaders(df, series_description, transform, batch_size=8):
    filtered_df = df[df['series_description'] == series_description]
    
    train_df, val_df = train_test_split(filtered_df, test_size=0.2, random_state=42)
    train_df = train_df.reset_index(drop=True)
    val_df = val_df.reset_index(drop=True)

    train_dataset = CustomDataset(train_df, transform)
    val_dataset = CustomDataset(val_df, transform)

    trainloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    valloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    return trainloader, valloader, len(train_df), len(val_df)

# %%
# Define the transforms
transform = transforms.Compose([
    transforms.Lambda(lambda x: (x * 255).astype(np.uint8)),
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
])

dataloaders = {}
lengths = {}

trainloader_t1, valloader_t1, len_train_t1, len_val_t1 = create_datasets_and_loaders(train_data, 'Sagittal T1', transform)
trainloader_t2, valloader_t2, len_train_t2, len_val_t2 = create_datasets_and_loaders(train_data, 'Axial T2', transform)
trainloader_t2stir, valloader_t2stir, len_train_t2stir, len_val_t2stir = create_datasets_and_loaders(train_data, 'Sagittal T2/STIR', transform)

dataloaders['Sagittal T1'] = (trainloader_t1, valloader_t1)
dataloaders['Axial T2'] = (trainloader_t2, valloader_t2)
dataloaders['Sagittal T2/STIR'] = (trainloader_t2stir, valloader_t2stir)

lengths['Sagittal T1'] = (len_train_t1, len_val_t1)
lengths['Axial T2'] = (len_train_t2, len_val_t2)
lengths['Sagittal T2/STIR'] = (len_train_t2stir, len_val_t2stir)

# Dictionary mapping labels to indices
label_map = {'Mild': 0, 'Moderate': 1, 'Severe': 2}

# %%
# Function to visualize a batch of images
def visualize_batch(dataloader):
    images, labels = next(iter(dataloader))
    fig, axes = plt.subplots(1, len(images), figsize=(20, 5))
    for i, (img, lbl) in enumerate(zip(images, labels)):
        ax = axes[i]
        img = img.permute(1, 2, 0)  
        ax.imshow(img)
        ax.set_title(f"Label: {lbl}")
        ax.axis('off')
    plt.show()

# Visualize samples from each dataloader
print("Visualizing Sagittal T1 samples")
visualize_batch(trainloader_t1)
print("Visualizing Axial T2 samples")
visualize_batch(trainloader_t2)
print("Visualizing Sagittal T2/STIR samples")
visualize_batch(trainloader_t2stir)
# Out:
# Visualizing Sagittal T1 samples
# Visualizing Axial T2 samples
# Visualizing Sagittal T2/STIR samples

# %%
'''
image, label = next(iter(trainloader_t2))
sample = image[1].permute(1, 2, 0) 

plt.figsize=(8, 4)
plt.imshow(images[0], cmap='gray')
plt.title(label[0])
plt.axis('off')
plt.tight_layout()
plt.show()
'''
# Out:
# "\nimage, label = next(iter(trainloader_t2))\nsample = image[1].permute(1, 2, 0) \n\nplt.figsize=(8, 4)\nplt.imshow(images[0], cmap='gray')\nplt.title(label[0])\nplt.axis('off')\nplt.tight_layout()\nplt.show()\n"

# %% [markdown]
# <h3>Model<h3>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# EfficientNet focuses on scaling up CNNs in a structured, balanced way using a technique called compound scaling.

# %%
class CustomEfficientNetV2(nn.Module):
    def __init__(self, num_classes=3, pretrained_weights=None):
        super(CustomEfficientNetV2, self).__init__()
        self.model = models.efficientnet_v2_s(weights=None)
        if pretrained_weights:
            self.model.load_state_dict(torch.load(pretrained_weights))
        num_ftrs = self.model.classifier[-1].in_features
        self.model.classifier[-1] = nn.Linear(num_ftrs, num_classes)

    def forward(self, x):
        return self.model(x)

    def unfreeze_model(self):
        # Unfreeze the last 20 layers, keeping BatchNorm layers frozen
        for layer in list(self.model.features.children())[-20:]:
            if not isinstance(layer, nn.BatchNorm2d):
                for param in layer.parameters():
                    param.requires_grad = True
        
        # Unfreeze the classifier
        for param in self.model.classifier.parameters():
            param.requires_grad = True

# %%
# Define the directory where you want to save the weights
save_dir = 'data/input/efficientnetv2/pytorch/efficientnetv2s/1'
os.makedirs(save_dir, exist_ok=True)  

# Download EfficientNetV2 Small weights from PyTorch's model hub 
weights_path = os.path.join(save_dir, 'efficientnet_v2_s-dd5fe13b.pth')
torch.hub.download_url_to_file('https://download.pytorch.org/models/efficientnet_v2_s-dd5fe13b.pth', weights_path)

print(f"Weights downloaded and saved to {weights_path}")
# Out:
# 100%|██████████| 82.7M/82.7M [00:03<00:00, 24.4MB/s]
# Weights downloaded and saved to data/input/efficientnetv2/pytorch/efficientnetv2s/1\efficientnet_v2_s-dd5fe13b.pth

# %%
weights_path = 'data/input/efficientnetv2/pytorch/efficientnetv2s/1/efficientnet_v2_s-dd5fe13b.pth'

# Initialize models
sagittal_t1_model = CustomEfficientNetV2(num_classes=3, pretrained_weights=weights_path).to(device)
axial_t2_model = CustomEfficientNetV2(num_classes=3, pretrained_weights=weights_path).to(device)
sagittal_t2stir_model = CustomEfficientNetV2(num_classes=3, pretrained_weights=weights_path).to(device)

# Optionally freeze initial layers
for param in sagittal_t1_model.model.features.parameters():
    param.requires_grad = False
for param in axial_t2_model.model.features.parameters():
    param.requires_grad = False
for param in sagittal_t2stir_model.model.features.parameters():
    param.requires_grad = False

# Unfreeze the final fully connected layer
for param in sagittal_t1_model.model.classifier.parameters():
    param.requires_grad = True
for param in axial_t2_model.model.classifier.parameters():
    param.requires_grad = True
for param in sagittal_t2stir_model.model.classifier.parameters():
    param.requires_grad = True

# Training parameters
criterion = nn.CrossEntropyLoss()

# Initialize separate optimizers for each model
optimizer_sagittal_t1 = torch.optim.Adam(sagittal_t1_model.model.classifier.parameters(), lr=0.001)
optimizer_axial_t2 = torch.optim.Adam(axial_t2_model.model.classifier.parameters(), lr=0.001)
optimizer_sagittal_t2stir = torch.optim.Adam(sagittal_t2stir_model.model.classifier.parameters(), lr=0.001)

# Store the models and optimizers in dictionaries for easy access
models = {
    'Sagittal T1': sagittal_t1_model,
    'Axial T2': axial_t2_model,
    'Sagittal T2/STIR': sagittal_t2stir_model,
}
optimizers = {
    'Sagittal T1': optimizer_sagittal_t1,
    'Axial T2': optimizer_axial_t2,
    'Sagittal T2/STIR': optimizer_sagittal_t2stir,
}
# Out:
# C:\Users\daivi\AppData\Local\Temp\ipykernel_6108\1453674981.py:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(pretrained_weights))

# %%
# Count trainable parameters
trainable_params = sum(p.numel() for p in sagittal_t1_model.parameters() if p.requires_grad)
print(f"Number of parameters: {trainable_params}")
# Out:
# Number of parameters: 3843

# %% [markdown]
# ## Next Steps:
#
# 1. **Train the model.**
# 2. **Test the model.**
# 3. **Aim to achieve an accuracy greater than 80%.**
